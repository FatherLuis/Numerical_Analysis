# %% [markdown]
# Luis E Vargas Tamayo <br>
# MATH 5360 <br>
# Dr. Thron <br>
# 27 October 2019 <br>

# %% [markdown]
# ### Question 8
#
# For 100 evenly spaced values of θ from 0 to 2π, plot the values of c(θ)  in the complex plane. (in your plot, you should be plotting the real part of c on the x axis and the imaginary part of c on the y axis).  Draw an important conclusion from your result.
#
# $c(\theta) =\frac{1}{4} - \frac{1}{4}[ cis(\theta)-1 ]^2$ <br><br>
# $c(\theta) =\frac{1}{4} - \frac{1}{4}[ cos(\theta)+i*sin(\theta)-1 ]^2$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def c(theta):
    return 0.25 - 0.25 * (np.cos(theta) + 1j*np.sin(theta)-1)**2

theta = np.linspace(0,2*np.pi,100)

cVal = c(theta)

plt.plot(cVal.real,cVal.imag)

# %% [markdown]
# ### Question 10

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt 

n = 50 # Number of different points on the graph
m = 100 # Number of different Thetas
r = 0.25
theta = np.arange(m)*(2*np.pi/m) # Array with different thetas
cVec= r*(np.cos(theta)+1j*np.sin(theta)) # Array with different points

def Mandelbrot(x, c):
    return x**2 + c

values=np.zeros((n,m))*1j

temp = cVec

for xx in range(n):
    values[xx] = temp
    temp= Mandelbrot(temp, cVec)

plt.plot(values.real,values.imag,'.')
# Out:
# [<matplotlib.lines.Line2D at 0x2209d2005f8>,
#  <matplotlib.lines.Line2D at 0x2209d200198>,
#  <matplotlib.lines.Line2D at 0x2209d200128>,
#  <matplotlib.lines.Line2D at 0x2209d200320>,
#  <matplotlib.lines.Line2D at 0x2209d200518>,
#  <matplotlib.lines.Line2D at 0x2209d200710>,
#  <matplotlib.lines.Line2D at 0x2209d200908>,
#  <matplotlib.lines.Line2D at 0x2209d200b00>,
#  <matplotlib.lines.Line2D at 0x2209d200cf8>,
#  <matplotlib.lines.Line2D at 0x2209d200ef0>,
#  <matplotlib.lines.Line2D at 0x2209e3ce0b8>,
#  <matplotlib.lines.Line2D at 0x2209d22c1d0>,
#  <matplotlib.lines.Line2D at 0x2209d22c320>,
#  <matplotlib.lines.Line2D at 0x2209d22c470>,
#  <matplotlib.lines.Line2D at 0x2209d22c5c0>,
#  <matplotlib.lines.Line2D at 0x2209d22c710>,
#  <matplotlib.lines.Line2D at 0x2209d22c860>,
#  <matplotlib.lines.Line2D at 0x2209d22c9b0>,
#  <matplotlib.lines.Line2D at 0x2209d22cb00>,
#  <matplotlib.lines.Line2D at 0x2209d22cc50>,
#  <matplotlib.lines.Line2D at 0x2209d22cda0>,
#  <matplotlib.lines.Line2D at 0x2209d22cef0>,
#  <matplotlib.lines.Line2D at 0x2209cf09080>,
#  <matplotlib.lines.Line2D at 0x2209cf091d0>,
#  <matplotlib.lines.Line2D at 0x2209cf09320>,
#  <matplotlib.lines.Line2D at 0x2209cf09470>,
#  <matplotlib.lines.Line2D at 0x2209cf095c0>,
#  <matplotlib.lines.Line2D at 0x2209cf09710>,
#  <matplotlib.lines.Line2D at 0x2209cf09860>,
#  <matplotlib.lines.Line2D at 0x2209cf099b0>,
#  <matplotlib.lines.Line2D at 0x2209cf09b00>,
#  <matplotlib.lines.Line2D at 0x2209e3fd860>,
#  <matplotlib.lines.Line2D at 0x2209cf09da0>,
#  <matplotlib.lines.Line2D at 0x2209cf09ef0>,
#  <matplotlib.lines.Line2D at 0x2209cf11080>,
#  <matplotlib.lines.Line2D at 0x2209cf111d0>,
#  <matplotlib.lines.Line2D at 0x2209cf11320>,
#  <matplotlib.lines.Line2D at 0x2209cf11470>,
#  <matplotlib.lines.Line2D at 0x2209cf115c0>,
#  <matplotlib.lines.Line2D at 0x2209cf11710>,
#  <matplotlib.lines.Line2D at 0x2209cf11860>,
#  <matplotlib.lines.Line2D at 0x2209cf119b0>,
#  <matplotlib.lines.Line2D at 0x2209cf11b00>,
#  <matplotlib.lines.Line2D at 0x2209cf11c50>,
#  <matplotlib.lines.Line2D at 0x2209cf11da0>,
#  <matplotlib.lines.Line2D at 0x2209cf11ef0>,
#  <matplotlib.lines.Line2D at 0x2209cf24080>,
#  <matplotlib.lines.Line2D at 0x2209cf241d0>,
#  <matplotlib.lines.Line2D at 0x2209cf24320>,
#  <matplotlib.lines.Line2D at 0x2209cf24470>,
#  <matplotlib.lines.Line2D at 0x2209cf245c0>,
#  <matplotlib.lines.Line2D at 0x2209cf24710>,
#  <matplotlib.lines.Line2D at 0x2209cf24860>,
#  <matplotlib.lines.Line2D at 0x2209cf249b0>,
#  <matplotlib.lines.Line2D at 0x2209cf24b00>,
#  <matplotlib.lines.Line2D at 0x2209cf24c50>,
#  <matplotlib.lines.Line2D at 0x2209cf24da0>,
#  <matplotlib.lines.Line2D at 0x2209cf24ef0>,
#  <matplotlib.lines.Line2D at 0x2209cf0e080>,
#  <matplotlib.lines.Line2D at 0x2209cf0e1d0>,
#  <matplotlib.lines.Line2D at 0x2209cf0e320>,
#  <matplotlib.lines.Line2D at 0x2209cf0e470>,
#  <matplotlib.lines.Line2D at 0x2209cf0e5c0>,
#  <matplotlib.lines.Line2D at 0x2209cf0e710>,
#  <matplotlib.lines.Line2D at 0x2209cf0e860>,
#  <matplotlib.lines.Line2D at 0x2209cf0e9b0>,
#  <matplotlib.lines.Line2D at 0x2209cf0eb00>,
#  <matplotlib.lines.Line2D at 0x2209cf0ec50>,
#  <matplotlib.lines.Line2D at 0x2209cf0eda0>,
#  <matplotlib.lines.Line2D at 0x2209cf0eef0>,
#  <matplotlib.lines.Line2D at 0x2209cef8080>,
#  <matplotlib.lines.Line2D at 0x2209cef81d0>,
#  <matplotlib.lines.Line2D at 0x2209cef8320>,
#  <matplotlib.lines.Line2D at 0x2209cef8470>,
#  <matplotlib.lines.Line2D at 0x2209cef85c0>,
#  <matplotlib.lines.Line2D at 0x2209cef8710>,
#  <matplotlib.lines.Line2D at 0x2209cef8860>,
#  <matplotlib.lines.Line2D at 0x2209cef89b0>,
#  <matplotlib.lines.Line2D at 0x2209cef8b00>,
#  <matplotlib.lines.Line2D at 0x2209cef8c50>,
#  <matplotlib.lines.Line2D at 0x2209cef8da0>,
#  <matplotlib.lines.Line2D at 0x2209cef8ef0>,
#  <matplotlib.lines.Line2D at 0x2209cf2e080>,
#  <matplotlib.lines.Line2D at 0x2209cf2e1d0>,
#  <matplotlib.lines.Line2D at 0x2209cf2e320>,
#  <matplotlib.lines.Line2D at 0x2209cf2e470>,
#  <matplotlib.lines.Line2D at 0x2209cf2e5c0>,
#  <matplotlib.lines.Line2D at 0x2209cf2e710>,
#  <matplotlib.lines.Line2D at 0x2209cf2e860>,
#  <matplotlib.lines.Line2D at 0x2209cf2e9b0>,
#  <matplotlib.lines.Line2D at 0x2209cf2eb00>,
#  <matplotlib.lines.Line2D at 0x2209cf2ec50>,
#  <matplotlib.lines.Line2D at 0x2209cf2eda0>,
#  <matplotlib.lines.Line2D at 0x2209cf2eef0>,
#  <matplotlib.lines.Line2D at 0x2209cf22080>,
#  <matplotlib.lines.Line2D at 0x2209cf221d0>,
#  <matplotlib.lines.Line2D at 0x2209cf22320>,
#  <matplotlib.lines.Line2D at 0x2209cf22470>,
#  <matplotlib.lines.Line2D at 0x2209cf225c0>,
#  <matplotlib.lines.Line2D at 0x2209cf22710>]

# %% [markdown]
# ### Question 11:
#
# Use the reference to locate a bulb  (also called “decoration”)  of period 3. Locate 3 points inside the bulb, and make 4 plots.   on the first plot, show all terms of the Mandelbrot sequence for the 3 points.  For the second plot, show the terms (i.e. z_0,z_3,z_6,…).  On the third  plot, show only the terms  z_1,z_4,z_7,… . On the fourth plot, show the terms z_2,z_5,z_8,… . Explain how your results show that the sequence is period 3.

# %% [markdown]
# ### Question 12:
#
# Another set that is closely related to the Mandelbrot set is the Julia set. The Julia set for the complex number c  is the set of complex numbers z such that the iterated function sequence {z,f_c (z),f_c(f_c (z)),f_c (f_c (f_c (z))),…,} remains bounded.  Note the difference between Julia sets and Mandelbrot sets: for the Mandelbrot set the starting point is always c ,while for the Julia set the starting point can be any complex number z. <br><br>
# As with the Mandelbrot set, we can make color plots using the following function:
# Index(z) = the smallest value of n such that $|z_n > 2|$, where z_n is the n’th term of the iterated function sequence.
# Take your Mandelbrot set code and modify it to create a diaram of the Julia set corresponding to c=-0.52+0.57i, which is shown below.<br><br>
#
# In your plot, take -2≤x,y≤2  (note that x and y are the real and imaginary parts respectively of the complex number z). At the beginning, you may take 200 x values and 200 y values, and take the maximum number of iterations equal to 32.  Your colors may not be the same as in the picture, but the shape should be the same.
