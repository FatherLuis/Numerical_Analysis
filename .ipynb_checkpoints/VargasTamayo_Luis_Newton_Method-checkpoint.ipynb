# %% [markdown]
# Use Newton's method to estimate a root of cos x. Initial guess is 2.
#
# Newton's method equation is:
# $$x_{i+1}=x_i + \frac{f(x_i)}{f'(x_i)}$$
#
# Relative error equation is
# $$\left|\epsilon_a\right|=\left|\frac{x_{i+1}-x_i}{x_{i+1}}\right|\times 100$$
#
# * Set the max number of iterations  for the method at 20
# * Set a minimum denominator of `1E-20`
# * Set a  tolerance of `5E-8` for the relative approximate error
#
# [Click here for Video link](https://youtu.be/n3SnbAtVYR4)

# %%
### Put here the commented code from the video
# Out:
# Root at:  1.5707963267948966  with tolerance  1e-10

# %% [markdown]
# 1.	Create four new cells as duplicates of original code.  Reproduce the results of Tables 1-4 in the text “mws_gen_nle_txt_newton.pdf” on these four cells, and include the four error terms from original (Max error, Actual error, Max relative error, Actual relative error).  (If you plot errors on a log scale, you should plot absolute values  of the errors because negative values won’t show.) Give the same graphs as in the original code when possible. When not possible, explain why.
# 2.	(Answer this part on a sheet of paper – scan and submit the scan as an attachment on Canvas.)  Use your code to estimate a root of $f(x) =x^3 - x$, starting with the initial guess $x_0=\frac{1}{\sqrt{5}}$.  What happens? Create a diagram (you can do on paper, or write a code) similar to Figure 1 in the text to explain what’s happening. (Make sure you show $x_{i+1}$ and $x_{i+2}$.)  What happens to Newton’s method when the initial guess is slightly smaller than $\frac{1}{\sqrt{5}}$? (Show $x_i x_{i+1} , x_{i+2}$ on the same diagram) When the initial guess is larger than $\frac{1}{\sqrt{5}}$, does the process always converge to the same value? Try a few different values, and show $x_i x_{i+1} , x_{i+2}$ for two different cases. (I recommend you use different colors for the different $x_i$’s).   What does this tell you in general about the choice of initial guesses for Newton’s method?
# 3.	Create another cell as a duplicate of the original. The function  $f(x) = a(x^2-x)+x$  has a root at $x=0$  for any value of $a$. Using an initial guess  of $x=1$, find the number of iterations it takes for Newton’s algorithm to converge within 0.0001 for $a=1$, $a=0.25$, and $a=0.0625$.  Output the results in a table. Which is converging faster?
# 4.	4.	Draw (on paper, or with software if you like)  a diagram similar to Figure 1 in the text for $f(x) = a(x^2-x)+x$  with $a=1$ and $a=0.25$. (draw both graphs on the same axis). Show $x_i, x_{i+1}$, and $x_{i+2}$  for each function. Note that the curvature of a function is determined by its second derivative. Compare the second derivatives of the two functions, and explain how the different convergence rates obtained in part (c) are related to the different curvatures of the different functions.
